# %% [markdown]
# # Project: Linear Regression First Part
#
# 1) Clean the dataset
#
# 2) Perform machine learning for linear regression

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# Load the dataset

# %%
# Loading our datasets
movies = pd.read_csv(r"C:\Users\alana\Documents\TecMTY\8vo_semestre\Data_Science\movie_project\datasets\Movies_Team3.csv")

# %% [markdown]
# We use the columns function to check the names and deduce their content. Some of them we might change it in order to have a better sintax

# %%
# checking out the columns
movies.columns
# Out:
# Index(['-', 'Genre', 'Year', 'Duration (min)', 'Budget (US)', 'Box_office',
#        'IMDB (Out of 10)', 'Personal_Rating (out of 10)', 'Critic_1',
#        'Critic_2', 'Critic_3', 'Critic_4', 'Person_1', 'Person_2', 'Person_3',
#        'Person_4', 'Person_5', 'Person_6', 'Person_7', 'Person_8', 'Person_9',
#        'Person_10', 'Person_11', 'Person_12', 'Person_13', 'Person_14',
#        'Person_15', 'Person_16', 'Person_17', 'Person_18', 'Person_19',
#        'Person_20', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36'],
#       dtype='object')

# %% [markdown]
# Checking out the content, printing last and first 5 values, where we can see that
#
# - The budget and Box office prices are huge, we are going to divide it over 1000000 to have smaller values
#
# - Eliminate the commas
#
# - Eliminate the rows from 204 till 999

# %%
movies.head(5)
# Out:
#                        -    Genre    Year  Duration (min)      Budget (US)  \
# 0     2 Fast and Furious   Action  2003.0           107.0   $76,000,000.00
# 1          A quiet place   Horror  2018.0            90.0   $17,000,000.00
# 2  A quiet place Part II   Horror  2020.0            97.0   $55,000,000.00
# 3          Aladin (2019)  Fantasy  2019.0           128.0  $183,000,000.00
# 4    Alice in Wonderland  Fantasy  2010.0           108.0  $205,000,000.00
#
#           Box_office  IMDB (Out of 10)  Personal_Rating (out of 10)  Critic_1  \
# 0    $236,350,661.00               5.9                         10.0       2.0
# 1    $340,939,361.00               7.5                          7.0       7.0
# 2    $297,400,000.00               7.2                          7.0       8.0
# 3  $1,050,693,953.00               6.9                          9.0       5.0
# 4  $1,028,467,110.00               6.4                          8.0       4.0
#
#    Critic_2  ...  Person_16  Person_17  Person_18  Person_19  Person_20  \
# 0       5.0  ...        5.0        6.0        4.0        6.0        6.0
# 1       9.0  ...        8.0        8.0        8.0        6.0       10.0
# 2       4.0  ...       10.0        8.0        4.0        8.0        9.0
# 3       7.0  ...        8.0        5.0        9.0        9.0       10.0
# 4       6.0  ...        8.0       10.0        8.0       10.0        9.0
#
#    Unnamed: 32  Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 37 columns]

# %%
movies.tail(5)
# Out:
#        - Genre  Year  Duration (min) Budget (US) Box_office  IMDB (Out of 10)  \
# 993  NaN   NaN   NaN             NaN         NaN        NaN               NaN
# 994  NaN   NaN   NaN             NaN         NaN        NaN               NaN
# 995  NaN   NaN   NaN             NaN         NaN        NaN               NaN
# 996  NaN   NaN   NaN             NaN         NaN        NaN               NaN
# 997  NaN   NaN   NaN             NaN         NaN        NaN               NaN
#
#      Personal_Rating (out of 10)  Critic_1  Critic_2  ...  Person_16  \
# 993                          NaN       NaN       NaN  ...        NaN
# 994                          NaN       NaN       NaN  ...        NaN
# 995                          NaN       NaN       NaN  ...        NaN
# 996                          NaN       NaN       NaN  ...        NaN
# 997                          NaN       NaN       NaN  ...        NaN
#
#      Person_17  Person_18  Person_19  Person_20  Unnamed: 32  Unnamed: 33  \
# 993        NaN        NaN        NaN        NaN          NaN          NaN
# 994        NaN        NaN        NaN        NaN          NaN          NaN
# 995        NaN        NaN        NaN        NaN          NaN          NaN
# 996        NaN        NaN        NaN        NaN          NaN          NaN
# 997        NaN        NaN        NaN        NaN          NaN          NaN
#
#      Unnamed: 34  Unnamed: 35  Unnamed: 36
# 993          NaN          NaN          NaN
# 994          NaN          NaN          NaN
# 995          NaN          NaN          NaN
# 996          NaN          NaN          NaN
# 997          NaN          NaN          NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# # Starting cleaning stage

# %% [markdown]
# 1) Renaming columns

# %%
movies = movies.rename(columns = {'-':'Title', 'Duration (min)':'Duration', 'Budget (US)':'Budget', 'Box_office':'Revenue', 'Personal_Rating (out of 10)':'PersonalRating', 'IMDB (Out of 10)':'IMDB'})
movies.columns
# Out:
# Index(['Title', 'Genre', 'Year', 'Duration', 'Budget', 'Revenue', 'IMDB',
#        'PersonalRating', 'Critic_1', 'Critic_2', 'Critic_3', 'Critic_4',
#        'Person_1', 'Person_2', 'Person_3', 'Person_4', 'Person_5', 'Person_6',
#        'Person_7', 'Person_8', 'Person_9', 'Person_10', 'Person_11',
#        'Person_12', 'Person_13', 'Person_14', 'Person_15', 'Person_16',
#        'Person_17', 'Person_18', 'Person_19', 'Person_20', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36'],
#       dtype='object')

# %%
movies.columns = [col.capitalize() for col in movies]
movies.columns
# Out:
# Index(['Title', 'Genre', 'Year', 'Duration', 'Budget', 'Revenue', 'Imdb',
#        'Personalrating', 'Critic_1', 'Critic_2', 'Critic_3', 'Critic_4',
#        'Person_1', 'Person_2', 'Person_3', 'Person_4', 'Person_5', 'Person_6',
#        'Person_7', 'Person_8', 'Person_9', 'Person_10', 'Person_11',
#        'Person_12', 'Person_13', 'Person_14', 'Person_15', 'Person_16',
#        'Person_17', 'Person_18', 'Person_19', 'Person_20', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36'],
#       dtype='object')

# %% [markdown]
# 2) Dropping unnecessary columns and rows

# %%
# Eliminating the last 5 columns
columns_to_drop = movies.columns[-5:]
movies = movies.drop(columns = columns_to_drop)

movies.columns
# Out:
# Index(['Title', 'Genre', 'Year', 'Duration', 'Budget', 'Revenue', 'Imdb',
#        'Personalrating', 'Critic_1', 'Critic_2', 'Critic_3', 'Critic_4',
#        'Person_1', 'Person_2', 'Person_3', 'Person_4', 'Person_5', 'Person_6',
#        'Person_7', 'Person_8', 'Person_9', 'Person_10', 'Person_11',
#        'Person_12', 'Person_13', 'Person_14', 'Person_15', 'Person_16',
#        'Person_17', 'Person_18', 'Person_19', 'Person_20'],
#       dtype='object')

# %%
# Eliminating rows 204 til 999
movies = movies.drop(movies.index[203:1000])

movies.tail(5)
# Out:
#                                    Title      Genre    Year  Duration  \
# 198  Wizards of Waverly Place: The Movie  Adventure  2009.0      98.0
# 199                  Wolf of Wall Street     Comedy  2013.0     180.0
# 200                       Wreck it ralph  Adventure  2012.0     101.0
# 201                                 Zoom     Comedy  2006.0      88.0
# 202                             Zootopia  Adventure  2016.0     108.0
#
#               Budget            Revenue  Imdb  Personalrating  Critic_1  \
# 198    $1,500,000.00                NaN   6.2             7.0       6.0
# 199  $100,000,000.00    $406,900,000.00   8.2             9.0       8.0
# 200  $165,000,000.00    $496,500,000.00   7.7             8.0       6.0
# 201   $75,600,000.00     $12,500,000.00   4.4             7.0       2.0
# 202  $150,000,000.00  $1,025,000,000.00   8.0             8.0       8.0
#
#      Critic_2  ...  Person_11  Person_12  Person_13  Person_14  Person_15  \
# 198       5.0  ...        6.0        6.0       10.0        8.0        6.0
# 199       6.0  ...        8.0        1.0        9.0       10.0        5.0
# 200       6.0  ...        9.0        8.0        8.0        9.0        9.0
# 201       4.0  ...        1.0        3.0        4.0        4.0        4.0
# 202       7.0  ...        9.0        8.0       10.0        7.0        4.0
#
#      Person_16  Person_17  Person_18  Person_19  Person_20
# 198        6.0       10.0        4.0        6.0        7.0
# 199       10.0        9.0        7.0        8.0        9.0
# 200        8.0        8.0       10.0        9.0        8.0
# 201       10.0        4.0        2.0        2.0        6.0
# 202       10.0        8.0       10.0        8.0        8.0
#
# [5 rows x 32 columns]

# %% [markdown]
# Now that we eliminate the unnecessary columns and rows, we proceed to eliminate the commas and $ sign from columns Revenue and Budget

# %%
# Eliminate commas and $ 
movies['Budget'] = movies['Budget'].str.replace(r'\$', '', regex=True)
movies['Budget'] = movies['Budget'].str.replace(',', '')

movies['Revenue'] = movies['Revenue'].str.replace(r'\$', '', regex=True)
movies['Revenue'] = movies['Revenue'].str.replace(',', '')

movies.head(5)
# Out:
#                    Title    Genre    Year  Duration        Budget  \
# 0     2 Fast and Furious   Action  2003.0     107.0   76000000.00
# 1          A quiet place   Horror  2018.0      90.0   17000000.00
# 2  A quiet place Part II   Horror  2020.0      97.0   55000000.00
# 3          Aladin (2019)  Fantasy  2019.0     128.0  183000000.00
# 4    Alice in Wonderland  Fantasy  2010.0     108.0  205000000.00
#
#          Revenue  Imdb  Personalrating  Critic_1  Critic_2  ...  Person_11  \
# 0   236350661.00   5.9            10.0       2.0       5.0  ...        5.0
# 1   340939361.00   7.5             7.0       7.0       9.0  ...        7.0
# 2   297400000.00   7.2             7.0       8.0       4.0  ...        6.0
# 3  1050693953.00   6.9             9.0       5.0       7.0  ...        5.0
# 4  1028467110.00   6.4             8.0       4.0       6.0  ...        9.0
#
#    Person_12  Person_13  Person_14  Person_15  Person_16  Person_17  \
# 0        7.0        6.0       10.0        4.0        5.0        6.0
# 1        8.0        8.0        8.0        8.0        8.0        8.0
# 2        7.0        5.0        8.0        7.0       10.0        8.0
# 3       10.0       10.0       10.0        7.0        8.0        5.0
# 4        6.0       10.0        6.0        5.0        8.0       10.0
#
#    Person_18  Person_19  Person_20
# 0        4.0        6.0        6.0
# 1        8.0        6.0       10.0
# 2        4.0        8.0        9.0
# 3        9.0        9.0       10.0
# 4        8.0       10.0        9.0
#
# [5 rows x 32 columns]

# %% [markdown]
# To avoid high numeric values, will divide the Budget over 100000. Although, first we need to check the type of data just to check if we need to do a convertion

# %%
# Checking out type of data
movies.dtypes
# Out:
# Title              object
# Genre              object
# Year              float64
# Duration          float64
# Budget             object
# Revenue            object
# Imdb              float64
# Personalrating    float64
# Critic_1          float64
# Critic_2          float64
# Critic_3          float64
# Critic_4          float64
# Person_1          float64
# Person_2          float64
# Person_3          float64
# Person_4          float64
# Person_5          float64
# Person_6          float64
# Person_7          float64
# Person_8          float64
# Person_9          float64
# Person_10         float64
# Person_11         float64
# Person_12         float64
# Person_13         float64
# Person_14         float64
# Person_15         float64
# Person_16         float64
# Person_17         float64
# Person_18         float64
# Person_19         float64
# Person_20         float64
# dtype: object

# %%
# As we have an object variable, we need to do a convertion before 
movies['Budget'] = movies['Budget'].astype(float)
movies['Budget'] = movies['Budget'] / 1000000

# Changing the variable type of Revenue, and then do the convertion
movies['Revenue'] = movies['Revenue'].astype(float)
movies['Revenue'] = movies['Revenue'] / 1000000

movies.head(1)
# Out:
#                 Title   Genre    Year  Duration  Budget     Revenue  Imdb  \
# 0  2 Fast and Furious  Action  2003.0     107.0    76.0  236.350661   5.9
#
#    Personalrating  Critic_1  Critic_2  ...  Person_11  Person_12  Person_13  \
# 0            10.0       2.0       5.0  ...        5.0        7.0        6.0
#
#    Person_14  Person_15  Person_16  Person_17  Person_18  Person_19  Person_20
# 0       10.0        4.0        5.0        6.0        4.0        6.0        6.0
#
# [1 rows x 32 columns]

# %% [markdown]
# All the rating columns must be rescaled

# %%
movies.columns
# Out:
# Index(['Title', 'Genre', 'Year', 'Duration', 'Budget', 'Revenue', 'Imdb',
#        'Personalrating', 'Critic_1', 'Critic_2', 'Critic_3', 'Critic_4',
#        'Person_1', 'Person_2', 'Person_3', 'Person_4', 'Person_5', 'Person_6',
#        'Person_7', 'Person_8', 'Person_9', 'Person_10', 'Person_11',
#        'Person_12', 'Person_13', 'Person_14', 'Person_15', 'Person_16',
#        'Person_17', 'Person_18', 'Person_19', 'Person_20'],
#       dtype='object')

# %%
rescale_columns = ['Imdb', 'Critic_1',
       'Critic_2', 'Critic_3', 'Personalrating', 'Person_1', 'Person_2', 'Person_3', 'Person_4',
       'Person_5', 'Person_6', 'Person_7', 'Person_8', 'Person_9', 'Person_10', 'Person_11',
       'Person_12', 'Person_13', 'Person_14', 'Person_15', 'Person_16', 'Person_17', 'Person_18',
       'Person_19', 'Person_20']

# %%
for col in rescale_columns:
    movies[col] = 10 * movies[col]

# %%
movies.iloc[:,0:10].describe()
# Out:
#               Year    Duration      Budget      Revenue        Imdb  \
# count   203.000000  203.000000  198.000000   198.000000  202.000000
# mean   2010.743842  115.837438   95.543404   496.358706  702.128713
# std      11.605879   25.275084   76.539075   488.777580  110.372158
# min    1942.000000   68.000000    0.636000     0.404923  210.000000
# 25%    2006.000000   97.000000   25.000000   169.659246  642.500000
# 50%    2013.000000  109.000000   85.000000   355.450000  720.000000
# 75%    2018.000000  131.500000  150.000000   701.775000  770.000000
# max    2024.000000  195.000000  365.000000  2923.706026  920.000000
#
#        Personalrating     Critic_1     Critic_2
# count      203.000000   203.000000   203.000000
# mean       849.261084   664.532020   654.679803
# std        137.649813   194.027539   188.835071
# min        100.000000   200.000000   200.000000
# 25%        800.000000   500.000000   500.000000
# 50%        900.000000   600.000000   600.000000
# 75%       1000.000000   800.000000   800.000000
# max       1000.000000  1000.000000  1000.000000

# %%
movies.iloc[:,10:].describe()
# Out:
#           Critic_3    Critic_4    Person_1    Person_2    Person_3  \
# count   203.000000  203.000000  203.000000  203.000000  203.000000
# mean    653.694581    6.605911   71.280788   74.285714   75.024631
# std     188.857024    1.791720   23.406333   22.839456   68.313303
# min       0.000000    2.000000   10.000000   10.000000   10.000000
# 25%     500.000000    6.000000   60.000000   60.000000   60.000000
# 50%     600.000000    7.000000   80.000000   80.000000   80.000000
# 75%     800.000000    8.000000   90.000000   90.000000   90.000000
# max    1000.000000   10.000000  100.000000  100.000000  980.000000
#
#           Person_4    Person_5    Person_6    Person_7    Person_8  ...  \
# count   203.000000  203.000000  203.000000  203.000000  203.000000  ...
# mean     76.650246   71.231527   72.463054   72.955665   70.344828  ...
# std      73.151212   23.207215   23.353554   23.675467   23.638769  ...
# min      10.000000   10.000000   10.000000   10.000000   10.000000  ...
# 25%      60.000000   60.000000   60.000000   60.000000   60.000000  ...
# 50%      80.000000   70.000000   80.000000   80.000000   80.000000  ...
# 75%      90.000000   90.000000   90.000000   90.000000   90.000000  ...
# max    1060.000000  100.000000  100.000000  100.000000  100.000000  ...
#
#         Person_11   Person_12   Person_13   Person_14   Person_15   Person_16  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean    72.413793   72.660099   71.428571   71.133005   72.512315   72.709360
# std     23.517135   24.001191   24.422611   23.403415   22.451126   23.568927
# min     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
# 25%     60.000000   60.000000   60.000000   60.000000   60.000000   60.000000
# 50%     80.000000   80.000000   80.000000   80.000000   80.000000   80.000000
# 75%     90.000000   90.000000   90.000000   90.000000   90.000000   90.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         Person_17   Person_18   Person_19   Person_20
# count  203.000000  203.000000  203.000000  203.000000
# mean    73.497537   71.625616   71.724138   72.807882
# std     23.695338   23.710668   24.625567   22.918226
# min     10.000000   10.000000   10.000000   10.000000
# 25%     60.000000   60.000000   60.000000   60.000000
# 50%     80.000000   80.000000   80.000000   80.000000
# 75%     90.000000   90.000000   90.000000   90.000000
# max    100.000000  100.000000  100.000000  100.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# # Export our new clean csv file
