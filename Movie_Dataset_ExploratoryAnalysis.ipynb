# %% [markdown]
# # Data Exploration

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading our clean dataset
movies = pd.read_csv(r'C:\Users\alana\Documents\TecMTY\8vo_semestre\Data_Science\movie_project\datasets\movies_team3_clean.csv', index_col='Title')

# %% [markdown]
# # Exploring the dataset

# %%
movies.head()
# Out:
#                        Unnamed: 0    Genre    Year  Duration  Budget  \
# Title
# 2 Fast and Furious              0   Action  2003.0     107.0    76.0
# A quiet place                   1   Horror  2018.0      90.0    17.0
# A quiet place Part II           2   Horror  2020.0      97.0    55.0
# Aladin (2019)                   3  Fantasy  2019.0     128.0   183.0
# Alice in Wonderland             4  Fantasy  2010.0     108.0   205.0
#
#                            Revenue  Imdb  Personalrating  Critic_1  Critic_2  \
# Title
# 2 Fast and Furious      236.350661  59.0           100.0      20.0      50.0
# A quiet place           340.939361  75.0            70.0      70.0      90.0
# A quiet place Part II   297.400000  72.0            70.0      80.0      40.0
# Aladin (2019)          1050.693953  69.0            90.0      50.0      70.0
# Alice in Wonderland    1028.467110  64.0            80.0      40.0      60.0
#
#                        ...  Person_11  Person_12  Person_13  Person_14  \
# Title                  ...
# 2 Fast and Furious     ...       50.0       70.0       60.0      100.0
# A quiet place          ...       70.0       80.0       80.0       80.0
# A quiet place Part II  ...       60.0       70.0       50.0       80.0
# Aladin (2019)          ...       50.0      100.0      100.0      100.0
# Alice in Wonderland    ...       90.0       60.0      100.0       60.0
#
#                        Person_15  Person_16  Person_17  Person_18  Person_19  \
# Title
# 2 Fast and Furious          40.0       50.0       60.0       40.0       60.0
# A quiet place               80.0       80.0       80.0       80.0       60.0
# A quiet place Part II       70.0      100.0       80.0       40.0       80.0
# Aladin (2019)               70.0       80.0       50.0       90.0       90.0
# Alice in Wonderland         50.0       80.0      100.0       80.0      100.0
#
#                        Person_20
# Title
# 2 Fast and Furious          60.0
# A quiet place              100.0
# A quiet place Part II       90.0
# Aladin (2019)              100.0
# Alice in Wonderland         90.0
#
# [5 rows x 32 columns]

# %%
movies.tail()
# Out:
#                                      Unnamed: 0      Genre    Year  Duration  \
# Title
# Wizards of Waverly Place: The Movie         198  Adventure  2009.0      98.0
# Wolf of Wall Street                         199     Comedy  2013.0     180.0
# Wreck it ralph                              200  Adventure  2012.0     101.0
# Zoom                                        201     Comedy  2006.0      88.0
# Zootopia                                    202  Adventure  2016.0     108.0
#
#                                      Budget  Revenue  Imdb  Personalrating  \
# Title
# Wizards of Waverly Place: The Movie     1.5      NaN  62.0            70.0
# Wolf of Wall Street                   100.0    406.9  82.0            90.0
# Wreck it ralph                        165.0    496.5  77.0            80.0
# Zoom                                   75.6     12.5  44.0            70.0
# Zootopia                              150.0   1025.0  80.0            80.0
#
#                                      Critic_1  Critic_2  ...  Person_11  \
# Title                                                    ...
# Wizards of Waverly Place: The Movie      60.0      50.0  ...       60.0
# Wolf of Wall Street                      80.0      60.0  ...       80.0
# Wreck it ralph                           60.0      60.0  ...       90.0
# Zoom                                     20.0      40.0  ...       10.0
# Zootopia                                 80.0      70.0  ...       90.0
#
#                                      Person_12  Person_13  Person_14  \
# Title
# Wizards of Waverly Place: The Movie       60.0      100.0       80.0
# Wolf of Wall Street                       10.0       90.0      100.0
# Wreck it ralph                            80.0       80.0       90.0
# Zoom                                      30.0       40.0       40.0
# Zootopia                                  80.0      100.0       70.0
#
#                                      Person_15  Person_16  Person_17  \
# Title
# Wizards of Waverly Place: The Movie       60.0       60.0      100.0
# Wolf of Wall Street                       50.0      100.0       90.0
# Wreck it ralph                            90.0       80.0       80.0
# Zoom                                      40.0      100.0       40.0
# Zootopia                                  40.0      100.0       80.0
#
#                                      Person_18  Person_19  Person_20
# Title
# Wizards of Waverly Place: The Movie       40.0       60.0       70.0
# Wolf of Wall Street                       70.0       80.0       90.0
# Wreck it ralph                           100.0       90.0       80.0
# Zoom                                      20.0       20.0       60.0
# Zootopia                                 100.0       80.0       80.0
#
# [5 rows x 32 columns]

# %%
movies.shape
# Out:
# (203, 32)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203 entries, 2 Fast and Furious to Zootopia
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      203 non-null    int64
#  1   Genre           203 non-null    object
#  2   Year            203 non-null    float64
#  3   Duration        203 non-null    float64
#  4   Budget          198 non-null    float64
#  5   Revenue         198 non-null    float64
#  6   Imdb            202 non-null    float64
#  7   Personalrating  203 non-null    float64
#  8   Critic_1        203 non-null    float64
#  9   Critic_2        203 non-null    float64
#  10  Critic_3        203 non-null    float64
#  11  Critic_4        203 non-null    float64
#  12  Person_1        203 non-null    float64
#  13  Person_2        203 non-null    float64
#  14  Person_3        203 non-null    float64
#  15  Person_4        203 non-null    float64
#  16  Person_5        203 non-null    float64
#  17  Person_6        203 non-null    float64
#  18  Person_7        203 non-null    float64
#  19  Person_8        203 non-null    float64
#  20  Person_9        203 non-null    float64
#  21  Person_10       203 non-null    float64
#  22  Person_11       203 non-null    float64
#  23  Person_12       203 non-null    float64
#  24  Person_13       203 non-null    float64
#  25  Person_14       203 non-null    float64
#  26  Person_15       203 non-null    float64
#  27  Person_16       203 non-null    float64
#  28  Person_17       203 non-null    float64
#  29  Person_18       203 non-null    float64
#  30  Person_19       203 non-null    float64
#  31  Person_20       203 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 52.3+ KB

# %% [markdown]
# # Fixing some details
#
# - As we can see, we have an extra column named 'Unnamed'. So we need to drop it

# %%
movies = movies.drop(columns=['Unnamed: 0'])

# %%
movies.head(1)
# Out:
#                      Genre    Year  Duration  Budget     Revenue  Imdb  \
# Title
# 2 Fast and Furious  Action  2003.0     107.0    76.0  236.350661  59.0
#
#                     Personalrating  Critic_1  Critic_2  Critic_3  ...  \
# Title                                                             ...
# 2 Fast and Furious           100.0      20.0      50.0      40.0  ...
#
#                     Person_11  Person_12  Person_13  Person_14  Person_15  \
# Title
# 2 Fast and Furious       50.0       70.0       60.0      100.0       40.0
#
#                     Person_16  Person_17  Person_18  Person_19  Person_20
# Title
# 2 Fast and Furious       50.0       60.0       40.0       60.0       60.0
#
# [1 rows x 31 columns]

# %% [markdown]
# # Creating a new fan rating
# To a better metric to evaluate the quality of the movies, we create a new column with the average of the persons grade

# %%
movies.iloc[:,11:]
# Out:
#                                      Person_1  Person_2  Person_3  Person_4  \
# Title
# 2 Fast and Furious                       80.0      70.0     100.0     100.0
# A quiet place                            60.0      90.0      50.0      90.0
# A quiet place Part II                    60.0      80.0      60.0      80.0
# Aladin (2019)                            50.0      70.0      90.0      80.0
# Alice in Wonderland                      80.0      70.0     100.0      20.0
# ...                                       ...       ...       ...       ...
# Wizards of Waverly Place: The Movie      90.0      70.0      70.0     100.0
# Wolf of Wall Street                      80.0      80.0      90.0     100.0
# Wreck it ralph                          100.0      60.0      70.0      70.0
# Zoom                                     30.0      40.0      30.0      60.0
# Zootopia                                 80.0      70.0      90.0     100.0
#
#                                      Person_5  Person_6  Person_7  Person_8  \
# Title
# 2 Fast and Furious                       30.0      90.0      60.0      30.0
# A quiet place                            90.0      90.0      70.0      60.0
# A quiet place Part II                    50.0      70.0      80.0      60.0
# Aladin (2019)                            80.0      70.0      80.0      80.0
# Alice in Wonderland                      90.0      90.0      70.0      90.0
# ...                                       ...       ...       ...       ...
# Wizards of Waverly Place: The Movie      60.0     100.0      40.0     100.0
# Wolf of Wall Street                      90.0      80.0      90.0      90.0
# Wreck it ralph                           70.0      80.0      70.0      80.0
# Zoom                                     60.0      30.0      10.0      10.0
# Zootopia                                 80.0      70.0      90.0      70.0
#
#                                      Person_9  Person_10  Person_11  \
# Title
# 2 Fast and Furious                       50.0       30.0       50.0
# A quiet place                            80.0       80.0       70.0
# A quiet place Part II                    60.0       60.0       60.0
# Aladin (2019)                           100.0      100.0       50.0
# Alice in Wonderland                      60.0       80.0       90.0
# ...                                       ...        ...        ...
# Wizards of Waverly Place: The Movie      60.0       90.0       60.0
# Wolf of Wall Street                      90.0      100.0       80.0
# Wreck it ralph                          100.0      100.0       90.0
# Zoom                                    100.0       20.0       10.0
# Zootopia                                 90.0       90.0       90.0
#
#                                      Person_12  Person_13  Person_14  \
# Title
# 2 Fast and Furious                        70.0       60.0      100.0
# A quiet place                             80.0       80.0       80.0
# A quiet place Part II                     70.0       50.0       80.0
# Aladin (2019)                            100.0      100.0      100.0
# Alice in Wonderland                       60.0      100.0       60.0
# ...                                        ...        ...        ...
# Wizards of Waverly Place: The Movie       60.0      100.0       80.0
# Wolf of Wall Street                       10.0       90.0      100.0
# Wreck it ralph                            80.0       80.0       90.0
# Zoom                                      30.0       40.0       40.0
# Zootopia                                  80.0      100.0       70.0
#
#                                      Person_15  Person_16  Person_17  \
# Title
# 2 Fast and Furious                        40.0       50.0       60.0
# A quiet place                             80.0       80.0       80.0
# A quiet place Part II                     70.0      100.0       80.0
# Aladin (2019)                             70.0       80.0       50.0
# Alice in Wonderland                       50.0       80.0      100.0
# ...                                        ...        ...        ...
# Wizards of Waverly Place: The Movie       60.0       60.0      100.0
# Wolf of Wall Street                       50.0      100.0       90.0
# Wreck it ralph                            90.0       80.0       80.0
# Zoom                                      40.0      100.0       40.0
# Zootopia                                  40.0      100.0       80.0
#
#                                      Person_18  Person_19  Person_20
# Title
# 2 Fast and Furious                        40.0       60.0       60.0
# A quiet place                             80.0       60.0      100.0
# A quiet place Part II                     40.0       80.0       90.0
# Aladin (2019)                             90.0       90.0      100.0
# Alice in Wonderland                       80.0      100.0       90.0
# ...                                        ...        ...        ...
# Wizards of Waverly Place: The Movie       40.0       60.0       70.0
# Wolf of Wall Street                       70.0       80.0       90.0
# Wreck it ralph                           100.0       90.0       80.0
# Zoom                                      20.0       20.0       60.0
# Zootopia                                 100.0       80.0       80.0
#
# [203 rows x 20 columns]

# %%
movies.iloc[:,11:].mean()
# Out:
# Person_1     71.280788
# Person_2     74.285714
# Person_3     75.024631
# Person_4     76.650246
# Person_5     71.231527
# Person_6     72.463054
# Person_7     72.955665
# Person_8     70.344828
# Person_9     72.512315
# Person_10    71.625616
# Person_11    72.413793
# Person_12    72.660099
# Person_13    71.428571
# Person_14    71.133005
# Person_15    72.512315
# Person_16    72.709360
# Person_17    73.497537
# Person_18    71.625616
# Person_19    71.724138
# Person_20    72.807882
# dtype: float64

# %%
# Creating the new column Fans which will have the average of each column
movies['Fans'] = movies.iloc[:,11:].mean(axis=1)

movies.head()
# Out:
#                          Genre    Year  Duration  Budget      Revenue  Imdb  \
# Title
# 2 Fast and Furious      Action  2003.0     107.0    76.0   236.350661  59.0
# A quiet place           Horror  2018.0      90.0    17.0   340.939361  75.0
# A quiet place Part II   Horror  2020.0      97.0    55.0   297.400000  72.0
# Aladin (2019)          Fantasy  2019.0     128.0   183.0  1050.693953  69.0
# Alice in Wonderland    Fantasy  2010.0     108.0   205.0  1028.467110  64.0
#
#                        Personalrating  Critic_1  Critic_2  Critic_3  ...  \
# Title                                                                ...
# 2 Fast and Furious              100.0      20.0      50.0      40.0  ...
# A quiet place                    70.0      70.0      90.0      80.0  ...
# A quiet place Part II            70.0      80.0      40.0      60.0  ...
# Aladin (2019)                    90.0      50.0      70.0      40.0  ...
# Alice in Wonderland              80.0      40.0      60.0      50.0  ...
#
#                        Person_12  Person_13  Person_14  Person_15  Person_16  \
# Title
# 2 Fast and Furious          70.0       60.0      100.0       40.0       50.0
# A quiet place               80.0       80.0       80.0       80.0       80.0
# A quiet place Part II       70.0       50.0       80.0       70.0      100.0
# Aladin (2019)              100.0      100.0      100.0       70.0       80.0
# Alice in Wonderland         60.0      100.0       60.0       50.0       80.0
#
#                        Person_17  Person_18  Person_19  Person_20  Fans
# Title
# 2 Fast and Furious          60.0       40.0       60.0       60.0  61.5
# A quiet place               80.0       80.0       60.0      100.0  77.5
# A quiet place Part II       80.0       40.0       80.0       90.0  69.0
# Aladin (2019)               50.0       90.0       90.0      100.0  81.5
# Alice in Wonderland        100.0       80.0      100.0       90.0  78.0
#
# [5 rows x 32 columns]

# %% [markdown]
# # Dropping columns with Null values
#
# - As we've seen before, there is presence of missing values in three columns of the dataset. So we need to drop it in order to not affect the machine learning model

# %%
movies.isnull().sum()
# Out:
# Genre             0
# Year              0
# Duration          0
# Budget            5
# Revenue           5
# Imdb              1
# Personalrating    0
# Critic_1          0
# Critic_2          0
# Critic_3          0
# Critic_4          0
# Person_1          0
# Person_2          0
# Person_3          0
# Person_4          0
# Person_5          0
# Person_6          0
# Person_7          0
# Person_8          0
# Person_9          0
# Person_10         0
# Person_11         0
# Person_12         0
# Person_13         0
# Person_14         0
# Person_15         0
# Person_16         0
# Person_17         0
# Person_18         0
# Person_19         0
# Person_20         0
# Fans              0
# dtype: int64

# %%
# We eliminate the columns with missing values
movies.dropna(inplace = True)

# %%
movies.shape
# Out:
# (193, 32)

# %% [markdown]
# # Stadistical analysis

# %% [markdown]
# Summary

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193 entries, 2 Fast and Furious to Zootopia
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Genre           193 non-null    object
#  1   Year            193 non-null    float64
#  2   Duration        193 non-null    float64
#  3   Budget          193 non-null    float64
#  4   Revenue         193 non-null    float64
#  5   Imdb            193 non-null    float64
#  6   Personalrating  193 non-null    float64
#  7   Critic_1        193 non-null    float64
#  8   Critic_2        193 non-null    float64
#  9   Critic_3        193 non-null    float64
#  10  Critic_4        193 non-null    float64
#  11  Person_1        193 non-null    float64
#  12  Person_2        193 non-null    float64
#  13  Person_3        193 non-null    float64
#  14  Person_4        193 non-null    float64
#  15  Person_5        193 non-null    float64
#  16  Person_6        193 non-null    float64
#  17  Person_7        193 non-null    float64
#  18  Person_8        193 non-null    float64
#  19  Person_9        193 non-null    float64
#  20  Person_10       193 non-null    float64
#  21  Person_11       193 non-null    float64
#  22  Person_12       193 non-null    float64
#  23  Person_13       193 non-null    float64
#  24  Person_14       193 non-null    float64
#  25  Person_15       193 non-null    float64
#  26  Person_16       193 non-null    float64
#  27  Person_17       193 non-null    float64
#  28  Person_18       193 non-null    float64
#  29  Person_19       193 non-null    float64
#  30  Person_20       193 non-null    float64
#  31  Fans            193 non-null    float64
# dtypes: float64(31), object(1)
# memory usage: 49.8+ KB

# %%
movies.describe()
# Out:
#               Year    Duration      Budget      Revenue        Imdb  \
# count   193.000000  193.000000  193.000000   193.000000  193.000000
# mean   2010.398964  116.119171   96.518622   506.372989   70.580311
# std      11.710990   25.048106   76.867460   490.337053   10.958018
# min    1942.000000   70.000000    0.636000     0.621392   21.000000
# 25%    2006.000000   97.000000   25.000000   173.567581   66.000000
# 50%    2013.000000  110.000000   85.000000   362.200000   72.000000
# 75%    2018.000000  131.000000  150.000000   724.998540   77.000000
# max    2023.000000  195.000000  365.000000  2923.706026   92.000000
#
#        Personalrating    Critic_1    Critic_2    Critic_3    Critic_4  ...  \
# count      193.000000  193.000000  193.000000  193.000000  193.000000  ...
# mean        85.336788   66.683938   65.699482   65.336788    6.621762  ...
# std         12.748184   19.562629   19.084594   18.819747    1.769811  ...
# min         40.000000   20.000000   20.000000    0.000000    2.000000  ...
# 25%         80.000000   60.000000   50.000000   50.000000    6.000000  ...
# 50%         90.000000   60.000000   60.000000   60.000000    7.000000  ...
# 75%        100.000000   80.000000   80.000000   80.000000    8.000000  ...
# max        100.000000  100.000000  100.000000  100.000000   10.000000  ...
#
#         Person_12   Person_13   Person_14   Person_15   Person_16   Person_17  \
# count  193.000000  193.000000  193.000000  193.000000  193.000000  193.000000
# mean    73.419689   71.606218   71.658031   73.056995   73.730570   74.196891
# std     23.666851   24.558823   23.169375   22.043562   23.039141   23.060215
# min     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
# 25%     60.000000   60.000000   60.000000   60.000000   60.000000   60.000000
# 50%     80.000000   80.000000   80.000000   80.000000   80.000000   80.000000
# 75%     90.000000   90.000000   90.000000   90.000000   90.000000   90.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         Person_18   Person_19   Person_20        Fans
# count  193.000000  193.000000  193.000000  193.000000
# mean    72.124352   71.658031   73.523316   73.121762
# std     23.187305   24.310216   22.291177   17.041752
# min     10.000000   10.000000   10.000000   27.500000
# 25%     60.000000   60.000000   60.000000   64.000000
# 50%     80.000000   80.000000   80.000000   75.000000
# 75%     90.000000   90.000000   90.000000   86.000000
# max    100.000000  100.000000  100.000000  134.500000
#
# [8 rows x 31 columns]

# %%
movies['Year']=movies['Year'].astype(str)
movies.describe()
# Out:
#          Duration      Budget      Revenue        Imdb  Personalrating  \
# count  193.000000  193.000000   193.000000  193.000000      193.000000
# mean   116.119171   96.518622   506.372989   70.580311       85.336788
# std     25.048106   76.867460   490.337053   10.958018       12.748184
# min     70.000000    0.636000     0.621392   21.000000       40.000000
# 25%     97.000000   25.000000   173.567581   66.000000       80.000000
# 50%    110.000000   85.000000   362.200000   72.000000       90.000000
# 75%    131.000000  150.000000   724.998540   77.000000      100.000000
# max    195.000000  365.000000  2923.706026   92.000000      100.000000
#
#          Critic_1    Critic_2    Critic_3    Critic_4    Person_1  ...  \
# count  193.000000  193.000000  193.000000  193.000000  193.000000  ...
# mean    66.683938   65.699482   65.336788    6.621762   71.398964  ...
# std     19.562629   19.084594   18.819747    1.769811   23.040078  ...
# min     20.000000   20.000000    0.000000    2.000000   10.000000  ...
# 25%     60.000000   50.000000   50.000000    6.000000   60.000000  ...
# 50%     60.000000   60.000000   60.000000    7.000000   80.000000  ...
# 75%     80.000000   80.000000   80.000000    8.000000   90.000000  ...
# max    100.000000  100.000000  100.000000   10.000000  100.000000  ...
#
#         Person_12   Person_13   Person_14   Person_15   Person_16   Person_17  \
# count  193.000000  193.000000  193.000000  193.000000  193.000000  193.000000
# mean    73.419689   71.606218   71.658031   73.056995   73.730570   74.196891
# std     23.666851   24.558823   23.169375   22.043562   23.039141   23.060215
# min     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
# 25%     60.000000   60.000000   60.000000   60.000000   60.000000   60.000000
# 50%     80.000000   80.000000   80.000000   80.000000   80.000000   80.000000
# 75%     90.000000   90.000000   90.000000   90.000000   90.000000   90.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         Person_18   Person_19   Person_20        Fans
# count  193.000000  193.000000  193.000000  193.000000
# mean    72.124352   71.658031   73.523316   73.121762
# std     23.187305   24.310216   22.291177   17.041752
# min     10.000000   10.000000   10.000000   27.500000
# 25%     60.000000   60.000000   60.000000   64.000000
# 50%     80.000000   80.000000   80.000000   75.000000
# 75%     90.000000   90.000000   90.000000   86.000000
# max    100.000000  100.000000  100.000000  134.500000
#
# [8 rows x 30 columns]
